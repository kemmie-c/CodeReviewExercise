# %% [markdown]
# <a href="https://colab.research.google.com/github/kemmie-c/CodeReviewExercise/blob/self_introduction/introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 鄭尌心
# 新北人
# 臨藥二
# 中山女高
